# %%
#pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from google.oauth2 import service_account

SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
KEY = 'clave.json'
# Escribe aquí el ID de tu documento:
SPREADSHEET_ID = '1WQjZkJKT7VHcK_aqLoC5ima7PD38P_944N0EGB5h9dY'

creds = None
creds = service_account.Credentials.from_service_account_file(KEY, scopes=SCOPES)

service = build('sheets', 'v4', credentials=creds)
sheet = service.spreadsheets()

# Llamada a la api
result = sheet.values().get(spreadsheetId=SPREADSHEET_ID, range='Directorio').execute()
# Extraemos values del resultado
values = result.get('values',[])
print(values)
# Out:
# [['Usuario', 'Correo Genérico', 'Correo Corporativo', 'Correo Power Bi', 'Tipo de informe', 'Celular', 'Cargo'], ['Alex chuica', 'Chuica_viera@hotmail.com', '-', ' AlexC@OLASB274.onmicrosoft.com', 'Pareto, food cost y venta semana', '-', '-'], ['Eloy Carrion', 'ecarrions190563@gmail.com', '', 'ecarrionse@OLASB274.onmicrosoft.com', 'Reporte General'], ['José Burranca', 'jburranca@gmail.com', 'jose.burranca@olas.pe', '-', 'Food Cost y Pareto'], ['Jackelin Farias', 'jackelinfarias123@gmail.com', '', 'Jfarias@OLASB274.onmicrosoft.com', 'Mkt, comensales y venta de productos'], ['Camilia Spirito', 'camidespiritobaiocchi@gmail.com', '', 'camilaS@OLASB274.onmicrosoft.com', 'Mkt, comensales y venta de productos'], ['Fernando Macher', 'fmm1977@hotmail.com', '', '', 'Ventas, food cost, comensales y mkt'], ['Ricardo Hernandez', 'ricardoalonsohernandezgarrido@gmail.com', '', 'rlogistica@OLASB274.onmicrosoft.com', 'Efectividad Mozos, Paretos y pedidos horas'], ['Gian Franco ', 'gianfrancochef_66@hotmail.com', '', '-', 'Food Cost, ventas semana y Pareto'], ['Diana Mendiguren', 'dianalu.men@gmail.com', '', 'dianaM@OLASB274.onmicrosoft.com', 'Pareto, Venta de productos y Food cost'], ['Luis Torres ', 'latcbar@gmail.com', 'luis.torres@olas.pe', '', 'Reporte General'], ['Erikson Abad', 'eriksonpublicista@gmail.com', 'erikson.abad@tahitiblue.pe', '-', 'Reporte General'], ['Regina Peña', 'requisha90@gmail.com', '', '', 'Costeo y pareto']]

# %%
# Convertimos los datos en un objeto de Pandas DataFrame
df = pd.DataFrame(values[1:], columns=values[0])

# Imprimimos el DataFrame
df
# Out:
#               Usuario                          Correo Genérico  \
# 0         Alex chuica                 Chuica_viera@hotmail.com
# 1        Eloy Carrion                ecarrions190563@gmail.com
# 2       José Burranca                      jburranca@gmail.com
# 3     Jackelin Farias              jackelinfarias123@gmail.com
# 4     Camilia Spirito          camidespiritobaiocchi@gmail.com
# 5     Fernando Macher                      fmm1977@hotmail.com
# 6   Ricardo Hernandez  ricardoalonsohernandezgarrido@gmail.com
# 7        Gian Franco             gianfrancochef_66@hotmail.com
# 8    Diana Mendiguren                    dianalu.men@gmail.com
# 9        Luis Torres                         latcbar@gmail.com
# 10       Erikson Abad              eriksonpublicista@gmail.com
# 11        Regina Peña                     requisha90@gmail.com
#
#             Correo Corporativo                      Correo Power Bi  \
# 0                            -       AlexC@OLASB274.onmicrosoft.com
# 1                               ecarrionse@OLASB274.onmicrosoft.com
# 2        jose.burranca@olas.pe                                    -
# 3                                  Jfarias@OLASB274.onmicrosoft.com
# 4                                  camilaS@OLASB274.onmicrosoft.com
# 5
# 6                               rlogistica@OLASB274.onmicrosoft.com
# 7                                                                 -
# 8                                   dianaM@OLASB274.onmicrosoft.com
# 9          luis.torres@olas.pe
# 10  erikson.abad@tahitiblue.pe                                    -
# 11
#
#                                Tipo de informe Celular Cargo
# 0             Pareto, food cost y venta semana       -     -
# 1                              Reporte General    None  None
# 2                           Food Cost y Pareto    None  None
# 3         Mkt, comensales y venta de productos    None  None
# 4         Mkt, comensales y venta de productos    None  None
# 5          Ventas, food cost, comensales y mkt    None  None
# 6   Efectividad Mozos, Paretos y pedidos horas    None  None
# 7            Food Cost, ventas semana y Pareto    None  None
# 8       Pareto, Venta de productos y Food cost    None  None
# 9                              Reporte General    None  None
# 10                             Reporte General    None  None
# 11                             Costeo y pareto    None  None
